# %%
import numpy as np
import pandas as pd
import sklearn.datasets
from scipy.special import digamma
import networkx as nx
import matplotlib.pyplot as plt
% matplotlib inline
import matplotlib
matplotlib.rcParams['pdf.fonttype'] = 42
import seaborn as sns
sns.set_style('ticks')
palette = sns.color_palette("RdBu_r", n_colors=25)

from depynd import bayesian_networks

# %%
iris = sklearn.datasets.load_iris()
df = pd.DataFrame(iris.data, columns=list(iris.feature_names))
df['target'] = iris.target
X = df.values

# %%
f, axes = plt.subplots(1, 2, figsize=[8, 4])
sns.heatmap(bayesian_networks.mmpc(X), ax=axes[0], cmap=palette, center=0, cbar=None, annot=True)
sns.heatmap(bayesian_networks.mmhc(X, verbose=True), ax=axes[1], cmap=palette, center=0, cbar=None, annot=True)
# Out:
# (2, 3) add 0.868633806237
# (3, 4) add 1.68627397673
# (0, 2) add 2.22713901104
# (0, 3) add 2.39371741084
# (2, 4) add 2.42876285694
# (0, 4) add 2.44447122547

# %%
g = nx.DiGraph(bayesian_networks.mmhc(X))
nx.draw_networkx(g, labels=dict(enumerate(df.columns)))
# Out:
# /home/ytakashina/anaconda3/envs/py36/lib/python3.6/site-packages/networkx/drawing/nx_pylab.py:522: MatplotlibDeprecationWarning: The is_string_like function was deprecated in version 2.1.
#   if not cb.is_string_like(edge_color) \
# /home/ytakashina/anaconda3/envs/py36/lib/python3.6/site-packages/networkx/drawing/nx_pylab.py:543: MatplotlibDeprecationWarning: The is_string_like function was deprecated in version 2.1.
#   if cb.is_string_like(edge_color) or len(edge_color) == 1:
# /home/ytakashina/anaconda3/envs/py36/lib/python3.6/site-packages/networkx/drawing/nx_pylab.py:724: MatplotlibDeprecationWarning: The is_string_like function was deprecated in version 2.1.
#   if not cb.is_string_like(label):

# %%
boston = sklearn.datasets.load_boston()
df = pd.DataFrame(boston.data, columns=list(boston.feature_names))
df['target'] = boston.target
X = df.values

# %%
f, axes = plt.subplots(1, 2, figsize=[8, 4])
sns.heatmap(bayesian_networks.iamb(X), ax=axes[0], cmap=palette, center=0, cbar=None, annot=True)
sns.heatmap(bayesian_networks.mmhc(X, verbose=True), ax=axes[1], cmap=palette, center=0, cbar=None, annot=True)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-2972f948168b> in <module>()
#       1 f, axes = plt.subplots(1, 2, figsize=[8, 4])
# ----> 2 sns.heatmap(bayesian_networks.iamb(X), ax=axes[0], cmap=palette, center=0, cbar=None, annot=True)
#       3 sns.heatmap(bayesian_networks.mmhc(X, verbose=True), ax=axes[1], cmap=palette, center=0, cbar=None, annot=True)
#
# /home/ytakashina/workspace/depynd/depynd/bayesian_networks.py in iamb(X, lamb, method, options)
#      60             for j in non_mb.nonzero()[0]:
#      61                 y = X[:, j]
# ---> 62                 cmi = conditional_mutual_information(x, y, z, method, options)
#      63                 if max_cmi < cmi:
#      64                     max_cmi = cmi
#
# /home/ytakashina/workspace/depynd/depynd/mutual_information.py in conditional_mutual_information(X, Y, Z, method, options)
#     127         Z = np.reshape(Z, [-1, 1])
#     128     XZ = np.hstack([X, Z])
# --> 129     mi_xz_y = mutual_information(XZ, Y, method, options)
#     130     mi_y_z = mutual_information(Y, Z, method, options)
#     131     return mi_xz_y - mi_y_z
#
# /home/ytakashina/workspace/depynd/depynd/mutual_information.py in mutual_information(X, Y, method, options)
#      96     else:
#      97         k = options.get('k', 3)
# ---> 98         return _mi_knn(X, Y, k)
#      99
#     100
#
# /home/ytakashina/workspace/depynd/depynd/mutual_information.py in _mi_knn(X, Y, k)
#      10     n, d_x = X.shape
#      11     _, d_y = Y.shape
# ---> 12     distances_x = np.linalg.norm(X - X.reshape([n, -1, d_x]), axis=2)
#      13     distances_y = np.linalg.norm(Y - Y.reshape([n, -1, d_y]), axis=2)
#      14     distances = np.maximum(distances_x, distances_y)
#
# KeyboardInterrupt:

# %%
g = nx.DiGraph(bayesian_networks.mmhc(X))
nx.draw_networkx(g, labels=dict(enumerate(df.columns)))
