# %%
import numpy as np
import pandas as pd
import sklearn.datasets
from scipy.special import digamma
import matplotlib.pyplot as plt
% matplotlib inline
import matplotlib
matplotlib.rcParams['pdf.fonttype'] = 42
import seaborn as sns
sns.set_style('ticks')
palette = sns.color_palette("RdBu_r", n_colors=25)

# %%
from depenpy import graph

# %%
data = sklearn.datasets.load_iris()
df = pd.DataFrame(data.data, columns=list(data.feature_names))
df['target'] = data.target
X = df.values

# %%
mis_knn = graph.mimat(X)
mis_dr = graph.mimat(X, method='dr')
cmis = graph.cmimat(X)

# %%
f, axes = plt.subplots(1, 3, figsize=[12, 4])
sns.heatmap(mis_knn, annot=True, center=0, cmap=palette, cbar=False, ax=axes[0])
sns.heatmap(mis_dr, annot=True, center=0, cmap=palette, cbar=False, ax=axes[1])
sns.heatmap(cmis, annot=True, center=0, cmap=palette, cbar=False, ax=axes[2])
